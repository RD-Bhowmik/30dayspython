# %%
age = 25 
height = 68.4
complex_num = 4 - 3j
area = int(input("Enter area: "))
print("The area is:", area)
radius = int(input("Enter radius: "))
print("The radius is:", radius)
area_of_triangle = 0.5 * area * radius
print("The area of the triangle is:", area_of_triangle)
# Out:
# The area is: 34
# The radius is: 1223982
# The area of the triangle is: 20807694.0

# %%
side_a = int(input("Enter side a: "))
print("The side a is:", side_a)
side_b = int(input("Enter side b: "))
print("The side b is:", side_b)
side_c = int(input("Enter side c: "))
print("The side c is:", side_c)

perimeter = side_a + side_b + side_c
print("The perimeter of the triangle is:", perimeter)
# Out:
# The side a is: 23
# The side b is: 23
# The side c is: 434
# The perimeter of the triangle is: 480

# %%
length = int(input("Enter length: "))
print("The length is:", length)
width = int(input("Enter width: "))
print("The width is:", width)

perimeter = 2 * (length + width)
print("The perimeter of the rectangle is:", perimeter)
# Out:
# The length is: 23
# The width is: 54
# The perimeter of the rectangle is: 154

# %%
radius = int(input("Enter radius: "))
print("The radius is:", radius)
pi = 3.14

area_of_circle = pi * radius * radius
print("The area of the circle is:", area_of_circle)

circum_of_circle = 2 * pi * radius
print("The circumference of the circle is:", circum_of_circle)
# Out:
# The radius is: 23
# The area of the circle is: 1661.06
# The circumference of the circle is: 144.44

# %%
# Calculate the slope, x-intercept and y-intercept of y = 2x -2

slope = 2
x_intercept = 1
y_intercept = -2
print("The slope is:", slope)
print("The x-intercept is:", x_intercept)
print("The y-intercept is:", y_intercept)

#Slope is (m = y2-y1/x2-x1). Find the slope and Euclidean distance between point (2, 2) and point (6,10)
import math
x1, y1 = 2, 2
x2, y2 = 6, 10
slope = (y2 - y1) / (x2 - x1)
distance = math.sqrt((x2 - x1)**2 + (y2 - y1)**2)
print("The slope between the points is:", slope)
print("The Euclidean distance between the points is:", distance)

print("Are the slopes equal?", slope == 2)
# Out:
# The slope is: 2
# The x-intercept is: 1
# The y-intercept is: -2
# The slope between the points is: 2.0
# The Euclidean distance between the points is: 8.94427190999916
# Are the slopes equal? True

# %%
while True:
    x = input("Enter a value for x (or 'q' to quit): ")
    if x == 'q':
        break
    x = float(x)
    y = x**2 + 6*x + 9
    print("For x =", x, ", y =", y)
    if y == 0:
        print("The value of y is zero.")
# Out:
# For x = 32.0 , y = 1225.0
# For x = 12.0 , y = 225.0
# For x = 0.0 , y = 9.0
# For x = 3.0 , y = 36.0
# For x = -10.0 , y = 49.0
# For x = 2.0 , y = 25.0
# For x = 3.0 , y = 36.0
# For x = 4.0 , y = 49.0
# For x = 5.0 , y = 64.0
# For x = -3.0 , y = 0.0
# The value of y is zero.
# For x = -4.0 , y = 1.0
# For x = -3.0 , y = 0.0
# The value of y is zero.
# For x = -2.0 , y = 1.0
# For x = -3.0 , y = 0.0
# The value of y is zero.
